# %%
# path to insight generation module
sys.path.append('C:/Users/01142128/Desktop/GitLab/turix-b/turixUI/dsServer')
from InsightGeneration import InsightGeneration
import pandas as pd

# %%
tools = InsightGeneration()

# %%
# this is your loaded dataframe
DataFrame = pd.read_csv('C:/Users/01142128/Desktop/GitLab/turix-b/Sample Data/creditcard.csv')

# load first your df into class var
tools.UpdatingDataFrame(DataFrame)

# %%
tools.ReadingData().columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
tools.ReadingData().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# individual insight
tools.FirstInsight('Amount') # for categorical
tools.FirstInsight('V2') # for numerical
# Out:
# Amount, have mean values 89. Meanwhile for minimum value is 0, and max value is 25692
# V2, have mean values 1. Meanwhile for minimum value is -72, and max value is 23

# %%
ls1 = ['V1_Group'] # this is your target variable
ls2 = ['V2_Group'] # this is your ranked variable
tools.SunBurstInsight(ls1, ls2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1304/987869790.py in <module>
#       1 ls1 = ['V1_Group'] # this is your target variable
#       2 ls2 = ['V2_Group'] # this is your ranked variable
# ----> 3 tools.SunBurstInsight(ls1, ls2)
#
# c:\Users\01142128\Desktop\GitLab\turix-b\turixUI\dsServer\InsightGeneration.py in SunBurstInsight(self, ls1, ls2)
#     357             ItemIter.append(i)
#     358
# --> 359             Pivot = self.PivotStacking(ls1, ItemIter)
#     360
#     361             _ , MinValues = self.GenerateMinStringFromPivot(ls1, ItemIter, Pivot)
#
# c:\Users\01142128\Desktop\GitLab\turix-b\turixUI\dsServer\InsightGeneration.py in PivotStacking(self, ls1, ls2)
#     170     # This will return final pivotting
#     171     def PivotStacking(self, ls1, ls2):
# ...

# %%
tools.ChartInsight('Class', 'V19', 'mean')
# Out:
# 1 in Class have highest mean value of V19 which is 0.68. Meanwhile 0 have lowest values which is -0.0
# 1 in Class appears 492 times in this data or 0.173 % from total data. Minimum values of Class that 1 have is -3.68. Meanwhile for the maximum values is 5.23.
# 0 in Class appears 284315 times in this data or 99.827 % from total data. Minimum values of Class that 0 have is -7.21. Meanwhile for the maximum values is 5.59.

# %%
# this is basicly data for sunburst insight
tools.PivotStacking(ls1, ls2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1788/1456091877.py in <module>
#       1 # this is basicly data for sunburst insight
# ----> 2 tools.PivotStacking(ls1, ls2)
#
# c:\Users\01142128\Desktop\GitLab\turix-b\turixUI\dsServer\InsightGeneration.py in PivotStacking(self, ls1, ls2)
#     170     # This will return final pivotting
#     171     def PivotStacking(self, ls1, ls2):
# --> 172         df = self.PivotTable(ls1, ls2).stack(self.CalculateStacking(ls2)).reset_index(name='Count')
#     173         df = df.sort_values(by='Count', ascending= False)
#     174         df.reset_index(drop=True, inplace=True)
#
# c:\Users\01142128\Desktop\GitLab\turix-b\turixUI\dsServer\InsightGeneration.py in PivotTable(self, ls1, ls2)
# ...

# %%
# this is basicly data for chart (bar or pie) insight, third argument you can change into mean, sum, max, or min
tools.CustomAggregation('Region', 'LoanTenure', 'mean')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15424/1191080065.py in <module>
#       1 # this is basicly data for chart (bar or pie) insight, third argument you can change into mean, sum, max, or min
# ----> 2 tools.CustomAggregation('Region', 'LoanTenure', 'mean')
#
# C:\Users/01142128/Desktop/GitLab/turix-b/turixUI/dsServer\InsightGeneration.py in CustomAggregation(self, XAxis, YAxis, Method)
#     208         custom_aggregation = {}
#     209         custom_aggregation[YAxis] = Method
# --> 210         df = self.ReadingData().groupby(XAxis).agg(custom_aggregation)
#     211         df.columns = [YAxis]
#     212         df[XAxis] = df.index
#
# ~\Anaconda3\envs\geo\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
# ...

# %%
tools.ReadingData().head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.098698  0.363787  0.090794 -0.551600 -0.617801 -0.991390 -0.311169
# 1  0.085102 -0.255425 -0.166974  1.612727  1.065235  0.489095 -0.143772
# 2  0.247676 -1.514654  0.207643  0.624501  0.066084  0.717293 -0.165946
# 3  0.377436 -1.387024 -0.054952 -0.226487  0.178228  0.507757 -0.287924
# 4 -0.270533  0.817739  0.753074 -0.822843  0.538196  1.345852 -1.119670
#
# ...

# %%
tools.CreateGroup('V2', [0.5,1], ['Fast', 'Medium', 'Slow'])
# Out:
# C:\Users\01142128\Anaconda3\envs\geo\lib\site-packages\pandas\core\indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# C:\Users\01142128\Anaconda3\envs\geo\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
tools.ReadingData().head()
# Out:
#    Time        V3        V4        V5        V6        V7        V8        V9  \
# 0   0.0  2.536347  1.378155 -0.338321  0.462388  0.239599  0.098698  0.363787
# 1   0.0  0.166480  0.448154  0.060018 -0.082361 -0.078803  0.085102 -0.255425
# 2   1.0  1.773209  0.379780 -0.503198  1.800499  0.791461  0.247676 -1.514654
# 3   1.0  1.792993 -0.863291 -0.010309  1.247203  0.237609  0.377436 -1.387024
# 4   2.0  1.548718  0.403034 -0.407193  0.095921  0.592941 -0.270533  0.817739
#
#         V10       V11       V12       V13       V14       V15       V16  \
# 0  0.090794 -0.551600 -0.617801 -0.991390 -0.311169  1.468177 -0.470401
# 1 -0.166974  1.612727  1.065235  0.489095 -0.143772  0.635558  0.463917
# 2  0.207643  0.624501  0.066084  0.717293 -0.165946  2.345865 -2.890083
# 3 -0.054952 -0.226487  0.178228  0.507757 -0.287924 -0.631418 -1.059647
# 4  0.753074 -0.822843  0.538196  1.345852 -1.119670  0.175121 -0.451449
#
# ...

# %%
tools.ResetModifiedDataFrame()

# %%
tools.ReadingData().head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6076/2030876973.py in <module>
# ----> 1 tools.ReadingData().head()
#
# c:\Users\01142128\Desktop\Proj\InsightGenerationMod.py in ReadingData(self)
#      58                 break
#      59
# ---> 60             if InsightGeneration.DataFrame is not None:
#      61                 OutputDataFrame = InsightGeneration.DataFrame
#      62                 break
#
# KeyboardInterrupt:
